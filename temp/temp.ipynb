# %%
for i in range(100):
    print("n" + str("%03d"%(i)))
# Out:
# n000
# n001
# n002
# n003
# n004
# n005
# n006
# n007
# n008
# n009
# n010
# n011
# n012
# n013
# n014
# n015
# n016
# n017
# n018
# n019
# n020
# n021
# n022
# n023
# n024
# n025
# n026
# n027
# n028
# n029
# n030
# n031
# n032
# n033
# n034
# n035
# n036
# n037
# n038
# n039
# n040
# n041
# n042
# n043
# n044
# n045
# n046
# n047
# n048
# n049
# n050
# n051
# n052
# n053
# n054
# n055
# n056
# n057
# n058
# n059
# n060
# n061
# n062
# n063
# n064
# n065
# n066
# n067
# n068
# n069
# n070
# n071
# n072
# n073
# n074
# n075
# n076
# n077
# n078
# n079
# n080
# n081
# n082
# n083
# n084
# n085
# n086
# n087
# n088
# n089
# n090
# n091
# n092
# n093
# n094
# n095
# n096
# n097
# n098
# n099

# %%
for i in range(100):
    print("self.n%03d.textChanged.connect(self.read_nums)"%(i))
# Out:
# self.n000.textChanged.connect(self.read_nums)
# self.n001.textChanged.connect(self.read_nums)
# self.n002.textChanged.connect(self.read_nums)
# self.n003.textChanged.connect(self.read_nums)
# self.n004.textChanged.connect(self.read_nums)
# self.n005.textChanged.connect(self.read_nums)
# self.n006.textChanged.connect(self.read_nums)
# self.n007.textChanged.connect(self.read_nums)
# self.n008.textChanged.connect(self.read_nums)
# self.n009.textChanged.connect(self.read_nums)
# self.n010.textChanged.connect(self.read_nums)
# self.n011.textChanged.connect(self.read_nums)
# self.n012.textChanged.connect(self.read_nums)
# self.n013.textChanged.connect(self.read_nums)
# self.n014.textChanged.connect(self.read_nums)
# self.n015.textChanged.connect(self.read_nums)
# self.n016.textChanged.connect(self.read_nums)
# self.n017.textChanged.connect(self.read_nums)
# self.n018.textChanged.connect(self.read_nums)
# self.n019.textChanged.connect(self.read_nums)
# ...

# %%
for i in range(100):
    print("temp_state.append(int(self.ui.n%03d.toPlainText()))"%(i))
# Out:
# temp_state.append(int(self.ui.n000.toPlainText()))
# temp_state.append(int(self.ui.n001.toPlainText()))
# temp_state.append(int(self.ui.n002.toPlainText()))
# temp_state.append(int(self.ui.n003.toPlainText()))
# temp_state.append(int(self.ui.n004.toPlainText()))
# temp_state.append(int(self.ui.n005.toPlainText()))
# temp_state.append(int(self.ui.n006.toPlainText()))
# temp_state.append(int(self.ui.n007.toPlainText()))
# temp_state.append(int(self.ui.n008.toPlainText()))
# temp_state.append(int(self.ui.n009.toPlainText()))
# temp_state.append(int(self.ui.n010.toPlainText()))
# temp_state.append(int(self.ui.n011.toPlainText()))
# temp_state.append(int(self.ui.n012.toPlainText()))
# temp_state.append(int(self.ui.n013.toPlainText()))
# temp_state.append(int(self.ui.n014.toPlainText()))
# temp_state.append(int(self.ui.n015.toPlainText()))
# temp_state.append(int(self.ui.n016.toPlainText()))
# temp_state.append(int(self.ui.n017.toPlainText()))
# ...
